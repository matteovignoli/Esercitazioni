# %%
# %%writefile Formulario.py
def sommaduenum(x,y):
  #somma le variabili x ed y
  ris = x + y
  return ris

  from formulario import sommaduenum

def paridispari
  if x<0:
      return 'Il numero è neg'
  elif x==0:
      return 'Il numero inserito è zero, cambiare numero'
  else:
      return 'Il numero è pos'

def trovaparidispari(x):
  if x%2 == 0:
    return 'Il numero è pari'
  else: 
    return 'Il numero è dispari'

def areatriangolo(x,y):
    #trovo l'area del triangolo
    area = (x*y)/2
    return "L'area è: ", area

def perimetro(x,y,z):
#sommo i lati del triangolo
  return x+y+z

def perimetro(*x):
  sum(x)
#somma tutti i lati della figura
# Out:
# Overwriting Formulario.py
